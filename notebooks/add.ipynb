# %%
def add(a,b):
    return a + b

print(f'the answers are {add(2,3)}, {add(5,7)}, and {add(10,15)}')

# %%
def sum_list(values):
    sum = 0
    for i in range(len(values)-1):
        if i == 0:
            sum = add(values[i],values[i+1])
        else:
            sum = add(sum,values[i+1])
    return sum
