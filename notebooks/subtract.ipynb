# %%
def subtract(a,b):
    return a - b

# %%
#example calls
print(subtract(2,1))
print(subtract(10,5))
print(subtract(5,10))
# Out:
# 1
# 5
# -5

# %%
def dist_from_zero(x):
    if x < 0:
        return subtract(0, x)
    else:
        return x

# %%
dist_from_zero(-5)
# Out:
# 5
