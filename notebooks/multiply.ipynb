# %%
def multiply(a,b):
    x = a * b
    return x

# %%
multiply(3, 4)
# Out:
# 12

# %%
multiply(2,5)
# Out:
# 10

# %%
multiply(4,2)
# Out:
# 8

# %%
multiply(3.1,6)
# Out:
# 18.6

# %%
def multiply(a,b):
    x = a * b
    return x

def square(x):
    m = multiply(x,x)
    return m
print(square(3))
# Out:
# 9
